# %% [markdown]
# # Análisis Exploratorio de Datos

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
propinas = sns.load_dataset('tips')

# %%
propinas.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Matplotlib

# %%
#Gráfico de Barra
plt.bar(propinas['sex'],propinas['total_bill'])
plt.xlabel('Sexo')
plt.ylabel('Total de la Cuenta')
plt.title('Propinas')
plt.show()

# %%
plt.hist(propinas[propinas['sex']=='Male']['tip'],
         bins = 10, 
         alpha = 0.2, 
         color = 'blue',
         label ='Hombres')

plt.hist(propinas[propinas['sex']=='Female']['tip'],
         bins = 10, 
         alpha = 0.2, 
         color = 'pink',
         label ='Mujeres')

plt.axvline(propinas[propinas['sex']=='Male']['tip'].mean(), label = 'Avg.Male', color = 'blue')
plt.axvline(propinas[propinas['sex']=='Female']['tip'].mean(), label = 'Avg.Female', color = 'red')

plt.legend()
plt.show()

# %%
plt.scatter(propinas['tip'], propinas['total_bill'])
plt.show()

# %%
#Gráfico de linea
plt.plot(propinas.index,propinas['total_bill'])
plt.xlabel('Ordenes')
plt.ylabel('Total de la Cuenta')
plt.title('Propinas')
plt.show()

# %%
plt.boxplot(propinas['tip'])
plt.show()

# %%
propinas_time = propinas.groupby('time').sum()['total_bill']
propinas_time
# Out:
# C:\Users\jeanp\AppData\Local\Temp\ipykernel_5196\2423931317.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   propinas_time = propinas.groupby('time').sum()['total_bill']
# time
# Lunch     1167.47
# Dinner    3660.30
# Name: total_bill, dtype: float64

# %%
#Gráfico de pastel
plt.pie(x = propinas_time,
        labels = propinas_time.index, 
        autopct = '%.2f')
plt.show()

# %%
#Gráfico de estadísticos
plt.hist(propinas['tip'])
plt.show()

# %%
#diagrama de dispersion 
plt.scatter(propinas['tip'],propinas['total_bill'])
plt.show()

# %%
#diagrama de caja
plt.boxplot(propinas['tip'])
plt.show()

# %%
#COMBINACION DE GRAFICOS EN UN SOLO
plt.hist(propinas[propinas['sex']=='Female']['total_bill'], 
         bins=20, 
         alpha=0.2, 
         color='red', 
         label='Total Bill - Females')
plt.hist(propinas[propinas['sex']=='Male']['total_bill'], bins=20, alpha=0.2, color='blue', label='Total Bill - Females')
plt.axvline(propinas[propinas['sex']=='Female']['total_bill'].mean(), label='Avg Female', color='red')
plt.axvline(propinas[propinas['sex']=='Male']['total_bill'].mean(), label='Avg Male', color='blue')
plt.suptitle('Distribución de Total de la Cuenta por Sexo')
plt.legend()
plt.show()

# %% [markdown]
# # Seaborn

# %%
#Gráfico de Barra
sns.barplot(x=propinas['sex'],y=propinas['total_bill'],estimator=np.sum)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.histplot(propinas['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
#Grafico de barras de conteo
sns.countplot(x='sex',data=propinas)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.scatterplot(x = propinas['total_bill'], y = propinas['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(x = propinas['total_bill'], y = propinas['tip'], kind='scatter')

# %%
sns.jointplot(x = propinas['total_bill'], y = propinas['tip'], kind='hex')

# %%
sns.jointplot(x = propinas['total_bill'], y = propinas['tip'], kind='reg')

# %%
sns.pairplot(propinas)

# %%
#Gráfico de linea
sns.lineplot(x=propinas.index,y=propinas['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
#Gráfico de estadísticos
sns.histplot(propinas['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.scatterplot(x=propinas['tip'],y=propinas['total_bill'])
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.jointplot(x='total_bill',y='tip',data=propinas,kind='scatter')

# %%
sns.jointplot(x='total_bill',y='tip',data=propinas,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=propinas,kind='reg')

# %%
sns.pairplot(propinas)

# %%
sns.pairplot(propinas,hue='sex',palette='coolwarm')

# %%
sns.boxplot(x="day", y="total_bill", data=propinas,palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Puede hacer el dataframe completo con orient='h'
sns.boxplot(data=propinas,palette='rainbow',orient='h')
# Out:
# <Axes: >

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",data=propinas, palette="coolwarm")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
propinas.corr()
# Out:
# C:\Users\jeanp\AppData\Local\Temp\ipykernel_5196\1129005646.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   propinas.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(propinas.corr())
# Out:
# C:\Users\jeanp\AppData\Local\Temp\ipykernel_5196\1169887912.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(propinas.corr())
# <Axes: >

# %%
sns.heatmap(propinas.corr(),cmap='coolwarm',annot=True)
# Out:
# C:\Users\jeanp\AppData\Local\Temp\ipykernel_5196\98298064.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(propinas.corr(),cmap='coolwarm',annot=True)
# <Axes: >

# %%
#vamos a cargar otro set de datos que viene integrado en seaborn
vuelos = sns.load_dataset('flights')

# %%
vuelos.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
pvvuelos = vuelos.pivot_table(values='passengers',index='month',columns='year')
sns.heatmap(pvvuelos)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(pvvuelos,cmap='magma',linecolor='white',linewidths=1)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Solo cuadrículas
sns.PairGrid(iris)

# %%
# Luego mapea a la cuadrícula
g = sns.PairGrid(iris)
g.map(plt.scatter) #dibuja un scatter plot para todas las combinaciones de numeros

# %%
# Mapear las partes superior, inferior y diagonal
g = sns.PairGrid(iris) #creo la cuadricula
g.map_diag(plt.hist) #histograma para las cuadriculas diagonales
g.map_upper(plt.scatter) #dispersion para las cuadriculas superiores que no son parte de la diagonal
g.map_lower(sns.kdeplot) #densidad para las cuadriculas inferiores que no son parte de la diagonal

# %%
# Solo la cuadriculas
g = sns.FacetGrid(propinas, col="time", row="smoker")

# %%
g = sns.FacetGrid(propinas, col="time",  row="smoker")
g = g.map(plt.hist, "total_bill")

# %%
g = sns.FacetGrid(propinas, col="time",  row="smoker",hue='sex')
# Observe que los argumentos vienen después de la llamada plt.scatter
g = g.map(plt.scatter, "total_bill", "tip").add_legend()

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cufflinks
# Out:
# ...
#      -------------------------------------- 81.7/81.7 kB 916.7 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68725 sha256=4ba9f722657cf0389a1cec8892367d938e902ac68ed610843ae7ec1f86685bcc
#   Stored in directory: c:\users\jeanp\appdata\local\pip\cache\wheels\b1\8f\ec\b76ac80a14f3f5f59643cbc2eee7d78690b1bd158279f299dd
# Successfully built cufflinks
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from plotly.offline import init_notebook_mode, iplot
import cufflinks as cf

# %%
import plotly.express as px

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Datos falsos

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.745385 -0.293817  0.311485 -1.111442
# 1 -0.754186 -0.452103  0.700322 -1.159436
# 2 -0.128431 -1.098669 -0.155809  0.153665
# 3  0.157608 -0.378028  0.606089  2.240700
# 4 -0.922663 -1.304442 -2.587339  0.145956

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df2.head()
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %% [markdown]
# ## Scatter

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=10)
# Out:
# <div>                            <div id="81035685-1eda-4584-8b8a-0eae7616fb30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Bar Plots

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>                            <div id="86ee4fcb-7711-4070-857f-d948da8dc00e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.count().iplot(kind='bar')
# Out:
# <div>                            <div id="e46a43dd-b707-4dcd-8405-ee73b531d1c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Boxplots

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="4f4da4cb-a785-42a8-a74b-cba1dcc57eca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## 3d Surface

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>                            <div id="549123fd-6d4a-4ec3-9bce-e6cf7e2e6c48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Spread

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# C:\Users\jeanp\anaconda3\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#
# C:\Users\jeanp\anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
# <div>                            <div id="e132ad96-315b-45b6-b4c7-13be919bfb04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## histogram

# %%
df['A'].iplot(kind='hist',bins=25)
# Out:
# <div>                            <div id="a8d0aec1-a009-4bd6-9168-5d2585c41a2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>                            <div id="2c99435a-cc4f-473e-a762-ae7c84f9f848" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## scatter_matrix()
#
# Similar a sns.pairplot()

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="244f8725-a43c-4afb-966f-e99995e4821d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Fin
